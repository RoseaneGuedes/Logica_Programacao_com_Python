# %% [markdown]
# ## **Lógica de Programação com Python**

# %%
1+1
# Out:
# 2

# %%
"Roseane"
# Out:
# 'Roseane'

# %%
nome = "Roseane"

# %%
nome
# Out:
# 'Roseane'

# %%
idade = 29

# %%
idade
# Out:
# 29

# %%
print("O nome é Roseane e sua idade é 29 anos")
# Out:
# O nome é Roseane e sua idade é 29 anos

# %%
print(f"O nome é {nome} e sua idade é {idade} anos")
# Out:
# O nome é Roseane e sua idade é 29 anos

# %% [markdown]
# ## Parâmetros

# %%
nome="Diego"

# %%
def saudacao_com_parametros(nome_da_pessoa):
  print(f"Olá {nome_da_pessoa}")

# %%
saudacao_com_parametros(nome)
# Out:
# Olá Diego

# %% [markdown]
# ## Criando minha primeira função

# %%
def saudacao():
  nome=input("Qual o seu nome? ")
  print(f"Olá {nome}")

# %%
saudacao()
# Out:
# Qual o seu nome? Roseane
# Olá Roseane

# %% [markdown]
# ## Condicional

# %%
#@title
idade = 20
def verifica_se_pode_dirigir(idade):
  if idade>=18:
    print("Tem permissão para dirigir")
  else:
    print("Não tem permissão para dirigir")
verifica_se_pode_dirigir(idade)
# Out:
# Tem permissão para dirigir

# %% [markdown]
# ## Convertendo tipo para inteiro

# %%
def verifica_pode_dirigir_sem_parametro():
  idade=input("Qual sua idade? ")
  idade= int(idade)
  if idade>=18:
    print("Tem permissão para dirigir")
  else:
    print("Não tem permissão para dirigir")
verifica_pode_dirigir_sem_parametro()
# Out:
# Qual sua idade? 10
# Não tem permissão para dirigir

# %% [markdown]
# ## Lista

# %%
idade = 22
idade
# Out:
# 22

# %%
nome = "Roseane"
nome
# Out:
# 'Roseane'

# %%
type(idade)
# Out:
# int

# %%
type(nome)
# Out:
# str

# %%
idades = [18, 22, 15, 50]
type (idades)
# Out:
# list

# %%
idades [2]
# Out:
# 15

# %%
idades = [18, 22, 15, 50]
#         0   1   2   3
#         0  -3  -2  -1

# %%
idades [1]
# Out:
# 22

# %%
idades [0:2]
# Out:
# [18, 22]

# %%
idades [0:3]
# Lembrando que o último número da lista é excludente
# Out:
# [18, 22, 15]

# %%
idades [1:]
# Se não colocar nada depois do : o programa entende que é até o final
# Out:
# [22, 15, 50]

# %%
idades [-1]
# Programa vai fazer 0-1 e vai retornar ao último elemento
# Out:
# 50

# %% [markdown]
# ## Laços e loops

# %%
# for fora da função
def verifica_se_pode_dirigir(idade):
  if idade>=18:
    print(f" {idade} anos de idade, TEM permissão para dirigir")
  else:
    print(f" {idade} anos de idade, NÃO TEM permissão para dirigir")
for idade in idades:
  verifica_se_pode_dirigir(idade)
# Out:
#  18 anos de idade, TEM permissão para dirigir
#  22 anos de idade, TEM permissão para dirigir
#  15 anos de idade, NÃO TEM permissão para dirigir
#  50 anos de idade, TEM permissão para dirigir

# %%
# for dentro da função
def verifica_se_pode_dirigir(idades):
  for idade in idades:
    if idade >=18:
      print (f"{idade} anos de idade, TEM permissão para dirigir")
    else:
      print(f"{idade} anos de idade, NÃO TEM permissão para dirifir")

verifica_se_pode_dirigir(idades)
# Out:
# 18 anos de idade, TEM permissão para dirigir
# 22 anos de idade, TEM permissão para dirigir
# 15 anos de idade, NÃO TEM permissão para dirifir
# 50 anos de idade, TEM permissão para dirigir

# %% [markdown]
# # Boleano

# %%
idade = 18
idade >=18
# Out:
# True

# %%
idade = 15
idade >=18
# Out:
# False

# %%
permissoes = []
idades = [20, 14, 40]
def verifica_se_pode_dirigir (idades, permissoes):
  for idade in idades:
    if idade>=18:
      permissoes.append(True)
    else:
      permissoes.append(False)

verifica_se_pode_dirigir(idades, permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao == True:
    print ("Tem permissão para dirigir")
  else:
    print("Não tem permissão para dirigir")
# Out:
# Tem permissão para dirigir
# Não tem permissão para dirigir
# Tem permissão para dirigir

# %% [markdown]
# # Tipos em uma lista

# %%
lista = ["Guilherme", 28, True, "18"]
for elemento in lista :
  print (f"O elemento {elemento} é do tipo: ", type(elemento))
# Out:
# O elemento Guilherme é do tipo:  <class 'str'>
# O elemento 28 é do tipo:  <class 'int'>
# O elemento True é do tipo:  <class 'bool'>
# O elemento 18 é do tipo:  <class 'str'>

# %% [markdown]
# ## Import

# %%
from random import randrange, seed 
seed(11)
randrange (0, 11)
# Out:
# 7

# %%
notas_matematica = []
for notas in range (8):
  notas_matematica.append(randrange(0, 11))
notas_matematica
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

# %%
len(notas_matematica)
# Out:
# 8

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1, 9))
y =notas_matematica
plt.plot (x, y, marker="o")
plt.title("Notas matemática")
plt.xlabel("Provas")
plt.ylabel("Notas")
plt.show()
